# %% [markdown]
# # #Pre-processing in Machine Learning.
#
# Remember in machine learning, good data + good algorithm >>> bad data + excellent algorithm

# %%
#Load your data into a dataframe. 

#check for non-numeric values. Maybe that's a null value, or maybe that's a non-numeric data type. In that case, 
#check the datatypes in the dataframe, and mutate them to numeric ones. 
#don't forget to shuffle your data

#run a simple model without any pre-processing first. Get the performance. Then try adding a pre-processing method 
#re-evluate the performance.

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_squared_error as loss
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("train.csv")
np.random.seed(5)

# %%
#parition your data into categorical and non-categorical data as pre-processing can be done only 
# non-categorical i.e. continous data

# %%
df.head(10)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 5  11  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311
# 6  12  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311
# 7  13  0.09378  12.5   7.87     0  0.524  5.889  39.0  5.4509    5  311
# 8  14  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307
# 9  15  0.63796   0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# ...

# %%
#Try getting rid of outliers. Use different standard deviations for getting outliers. 
df_new = df[df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 4).all(axis=1)]

# %%
df.shape, df_new.shape
# Out:
# ((333, 13), (325, 13))

# %%
#Get correlations
corr = df.corr()
plt.rcParams["figure.figsize"] = (10,10)
sns.heatmap(corr, cmap = "coolwarm", annot = True)

# %%
#skew measures the un-normalness of data. positive valued skewed data with skew > 2 should be logged. 
#use df.skew to measure the skeweness of each feature.

# %%
#Try standardising the data. 

#Try normalising the data

# %%
#re-add categorical data if you're done with pre-processing.

# %%
#Analyse your features for uselessones. There's a particularly useless one here. Find it out. 
#Divide your table into inputs and target named "medv" column

# %%
#Train your first classifier and evaluate the accuracy on test data.

# %%
#Define a function call eval(inputs, outputs, trial, test_size) that takes a model object and prints the above diagnostics. It'll be useful as
#you'll need to call it again and again. Trials is the number of trails you'll be averaging it over.

# %%
# def eval(inputs, output, trials, tsize):
    #train the model 
    
    #calculate loss and accuracy for training data. Use sklearn.metrics.mean_squared_error() function for calculating 
    #the loss. Make sure you take the average loss and not the total loss. 

    #take an average of above trials on no. of trials    
    
    #print the metrics
